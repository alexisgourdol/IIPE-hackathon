# %% [markdown]
# # School inspection reports' analysis
#
# This code, which uses SoS as the background, is written in Python (for the data extraction and manipulation) and R (for the Topic analysis). The respective sections can be extracted and used separetely, or jointly by following the installation guidelines presented in the link below.
#
# https://vatlab.github.io/sos-docs/running.html#Local-installation
#
# The user should run the following lines from the Command Prompt
#
# - pip install sos-notebook
# - pip install sos-papermill
# - pip install sos-r
# - python -m sos_notebook.install
# - jupyter kernelspec list
#
# and choose SoS as the kernel for a new notebook. Please refer to Notebook Interface of the SoS documentation for details (https://vatlab.github.io/sos-docs/doc/documentation/Notebook_Interface.html)
#
# Data from Ireland taken from https://data.gov.ie/dataset/primary-schools and https://www.education.ie/en/Publications/Inspection-Reports-Publications/Whole-School-Evaluation-Reports-List

# %%
#!pyenv virtualenvs

# %%
#!pip install rpy2
#!pip install wget
#!pip install pdfminer.six
#!pip install geopandas
#!pip install geopy
#!pip install bs4
#!pip install pandas

# %%
# We import the necessary packages
import sys, os, csv, requests, re, bs4, datetime, time, threading, wget, pdfminer, geopandas, geopy
import pandas as pd
import matplotlib.pyplot as plt
from pdfminer.high_level import extract_text
from geopy.geocoders import Nominatim
import numpy as np

# %% [markdown]
# Select the appropriate working directory

# %%
os.getcwd()
# Out:
# '/Users/alexisgourdol/code/alexisgourdol/IIPE-data/notebooks'

# %%
if os.getcwd()!="/Users/alexisgourdol/code/alexisgourdol/IIPE-data/notebooks":
    print("Please insert the WORKING DIRECTORY")                                                            # We create a loop so that the user establishes the working directory
    print("Remember to separate the backslash (for Windows) or forward slash (in Mac)") 
    while True:                                                                             
        NewPath=input()                                                                                     # The user inserts the working directory
        if os.path.exists(NewPath)==True:                                                                   # If the program exists, the working directory will be updated
            os.chdir(NewPath)                                                               
            print("Your new path is " + os.getcwd())                                        
            break                                                                                           # If the condition is met, the program keeps running
        else:                                                                                               # If the condition is not met, the program requests the user to
            print("Please check if the path is correctly written")                                          # insert a new path and the condition is checked again
        continue
else: 
    print("Your path is " + os.getcwd())
# Out:
# Your path is /Users/alexisgourdol/code/alexisgourdol/IIPE-data/notebooks

# %% [markdown]
# ## Extracting the tables from the webpage and turning them into a DataFrame
#
# Note that his DataFrame will not only work to later download the corresponding reports, but it is a useful Metadata database, which can be then used to make analyses on the different results across time, location, or type of school.

# %% [markdown]
# If the error below occur, run `pip install lxml`
#
# _FeatureNotFound: Couldn't find a tree builder with the features you requested: lxml. Do you need to install a parser library?_

# %%
#!pip install lxml

# %%
WebpageRoot = "https://www.education.ie/en/Publications/Inspection-Reports-Publications/Whole-School-Evaluation-Reports-List/?pageNumber="
General_InspectionReports = pd.DataFrame(columns=['Date','School Roll No.','County','School Name','School Level','Inspection Type','Subject','URL'])

# Records:    1 to   20 of 3871
# Records:                             3861 to 3871 of 3871
# Pages:     1|    |     |     |     |   194 |
print("How many pages would you like to download?")

NumberPages = input()

for x in range(1,int(NumberPages)):
    IrelandWebpage = requests.get(WebpageRoot + str(x))
    CleanIrelandWebpage = bs4.BeautifulSoup(IrelandWebpage.text, "lxml")
    InspectionReports = {}
    ID = 0
    Table = CleanIrelandWebpage.find('table', id="IRList")
    for p in Table.find_all('tr'):
        if ID == 0:
            ID = ID + 1
            continue
        else:
            Date = p('td')[0].string[:2] + '_' + p('td')[0].string[3:5] + '_' + p('td')[0].string[6:]
            SchoolRoll = p('td')[1].string
            County = p('td')[2].string
            SchoolName = p('td')[3].string
            SchoolLevel = p('td')[4].string
            InspectionType = p('td')[5].string
            Subject = p('td')[6].string
            URL = p('td')[7]('a')[0].attrs['href'][86:]
            InspectionReports[ID] = {'Date': Date, 'School Roll No.': SchoolRoll, 'County': County, 'School Name': SchoolName, 'School Level': SchoolLevel, 'Inspection Type': InspectionType, 'Subject': Subject, 'URL': URL}
            ID = ID + 1

    df_InspectionReports = pd.DataFrame.from_dict(InspectionReports, orient='index')
    General_InspectionReports = pd.concat([General_InspectionReports,df_InspectionReports])
# Out:
# How many pages would you like to download?
# 1

# %%
df_InspectionReports.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-d7026d923db3> in <module>
# ----> 1 df_InspectionReports.head(3)
#
# NameError: name 'df_InspectionReports' is not defined

# %%
General_InspectionReports.head(3)
# Out:
# Empty DataFrame
# Columns: [Date, School Roll No., County, School Name, School Level, Inspection Type, Subject, URL]
# Index: []

# %% [markdown]
# ## Downloading the PDFs

# %%
PDFToConvert = []
for index, row in General_InspectionReports.iterrows():
    DownloadURL = 'https://www.education.ie/en/Publications/Inspection-Reports-Publications/Whole-School-Evaluation-Reports-List/' + row['URL']
    FileName = 'Reports\\' + row['School Roll No.'] + '_' + row['Date'] + '.pdf'
    PDFToConvert.append('Reports\\' + row['School Roll No.'] + '_' + row['Date'])
    print('Report ' + row['School Roll No.'] + ' downloaded')
    wget.download(DownloadURL, FileName)
# Out:
# Report 70660O downloaded
# Report 61811I downloaded
# Report 62360G downloaded
# Report 64810V downloaded
# Report 13299E downloaded
# Report 20440Q downloaded
# Report 16871V downloaded
# Report 17443F downloaded
# Report 70760S downloaded
# Report 12936D downloaded
# Report 07518E downloaded
# Report 19458F downloaded
# Report 20205G downloaded
# Report 60660I downloaded
# Report 62930V downloaded
# Report 71330V downloaded
# Report 14194S downloaded
# Report 19209H downloaded
# Report 12792F downloaded
# Report 81016V downloaded
# Report 91614B downloaded
# Report 91391H downloaded
# Report 72310U downloaded
# Report 20008E downloaded
# Report 20242M downloaded
# Report 62730N downloaded
# Report 64220A downloaded
# Report 19926M downloaded
# Report 64370T downloaded
# Report 65190W downloaded
# Report 18660S downloaded
# Report 70640I downloaded
# Report 20313J downloaded
# Report 20435A downloaded
# Report 17893N downloaded
# Report 65100S downloaded
# Report 70081V downloaded
# Report 60321J downloaded
# Report 20220C downloaded
# Report 20073P downloaded
# Report 62990Q downloaded
# Report 01300Q downloaded
# Report 05933G downloaded
# Report 16485Q downloaded
# Report 64760J downloaded
# Report 19985F downloaded
# Report 19507P downloaded
# Report 20422O downloaded
# Report 18062V downloaded
# Report 60030V downloaded
# Report 03917V downloaded
# Report 19435Q downloaded
# Report 12343W downloaded
# Report 17914S downloaded
# Report 19476H downloaded
# Report 19768U downloaded
# Report 19957A downloaded
# Report 60891E downloaded
# Report 64420I downloaded
# Report 91344V downloaded
# Report 17438M downloaded
# Report 64700O downloaded
# Report 60122D downloaded
# Report 81001I downloaded
# Report 62450H downloaded
# Report 18280I downloaded
# Report 70321P downloaded
# Report 14900P downloaded
# Report 17230L downloaded
# Report 68083N downloaded
# Report 76069P downloaded
# Report 60561G downloaded
# Report 91513S downloaded
# Report 19368E downloaded
# Report 71370K downloaded
# Report 20499D downloaded
# Report 20224K downloaded
# Report 19987J downloaded
# Report 17265H downloaded
# Report 17514C downloaded
# Report 18564W downloaded
# Report 70990M downloaded
# Report 20437E downloaded
# Report 60500J downloaded
# Report 20294I downloaded
# Report 68067P downloaded
# Report 19979K downloaded
# Report 20448J downloaded
# Report 20097G downloaded
# Report 09306W downloaded
# Report 18365Q downloaded
# Report 19692N downloaded
# Report 65450W downloaded
# Report 91447I downloaded
# Report 18396E downloaded
# Report 20052H downloaded
# Report 19348V downloaded
# Report 09069L downloaded
# Report 17872F downloaded
# Report 12068D downloaded
# Report 16648S downloaded
# Report 63650U downloaded
# Report 76086P downloaded
# Report 16159D downloaded
# Report 16976M downloaded
# Report 17253A downloaded
# Report 19776T downloaded
# Report 18033O downloaded
# Report 71650Q downloaded
# Report 11765U downloaded
# Report 68101M downloaded
# Report 15560W downloaded
# Report 19721R downloaded
# Report 20400E downloaded
# Report 20442U downloaded
# Report 20451V downloaded
# Report 61070P downloaded
# Report 68070E downloaded
# Report 19427R downloaded
# Report 20450T downloaded
# Report 20166W downloaded
# Report 20025E downloaded
# Report 63891T downloaded
# Report 62981P downloaded
# Report 20439I downloaded
# Report 19686S downloaded
# Report 71242B downloaded
# Report 03220F downloaded
# Report 19983B downloaded
# Report 20241K downloaded
# Report 20021T downloaded
# Report 60860Q downloaded
# Report 61920N downloaded
# Report 62650P downloaded
# Report 70790E downloaded
# Report 60290B downloaded
# Report 71390Q downloaded
# Report 08342V downloaded
# Report 61691B downloaded
# Report 71250A downloaded
# Report 19673J downloaded
# Report 60853T downloaded
# Report 18219F downloaded
# Report 20202A downloaded
# Report 71200I downloaded
# Report 15407O downloaded
# Report 17012B downloaded
# Report 71470O downloaded
# Report 19994G downloaded
# Report 19959E downloaded
# Report 65340P downloaded
# Report 91511O downloaded
# Report 19990V downloaded
# Report 14863M downloaded
# Report 91431Q downloaded
# Report 19796C downloaded
# Report 60340N downloaded
# Report 63451O downloaded
# Report 20058T downloaded
# Report 14305B downloaded
# Report 15496Q downloaded
# Report 17313P downloaded
# Report 18044T downloaded
# Report 20112W downloaded
# Report 17603B downloaded
# Report 18551N downloaded
# Report 20492M downloaded
# Report 20222G downloaded
# Report 13730L downloaded
# Report 60590N downloaded
# Report 17907V downloaded
# Report 76152C downloaded
# Report 16936A downloaded
# Report 62640M downloaded
# Report 19592J downloaded
# Report 71540J downloaded
# Report 72010I downloaded
# Report 17799V downloaded
# Report 91396R downloaded
# Report 19837N downloaded
# Report 20466L downloaded
# Report 16982H downloaded
# Report 17550G downloaded
# Report 19378H downloaded
# Report 63310T downloaded
# Report 18380M downloaded
# Report 91376L downloaded
# Report 19456B downloaded
# Report 20443W downloaded
# Report 01421F downloaded
# Report 05970M downloaded
# Report 14052V downloaded
# Report 12447L downloaded
# Report 20382F downloaded
# Report 15259C downloaded
# Report 19359D downloaded
# Report 65470F downloaded
# Report 15395K downloaded
# Report 16681Q downloaded
# Report 20155R downloaded
# Report 60310E downloaded
# Report 60042F downloaded
# Report 07315N downloaded
# Report 16893I downloaded
# Report 18820O downloaded
# Report 19734D downloaded
# Report 91456J downloaded
# Report 70260V downloaded
# Report 60130C downloaded
# Report 05630L downloaded
# Report 20002P downloaded
# Report 13607M downloaded
# Report 20333P downloaded
# Report 70570N downloaded
# Report 70620C downloaded
# Report 20212D downloaded
# Report 64170L downloaded
# Report 64250J downloaded
# Report 71780G downloaded
# Report 13775K downloaded
# Report 16116I downloaded
# Report 60690R downloaded
# Report 13781F downloaded
# Report 62661U downloaded
# Report 16138S downloaded
# Report 19546C downloaded
# Report 62330U downloaded
# Report 02114B downloaded
# Report 63280N downloaded
# Report 76233C downloaded
# Report 19461R downloaded
# Report 19314E downloaded
# Report 19408N downloaded
# Report 61681V downloaded
# Report 16375J downloaded
# Report 60291D downloaded
# Report 63910U downloaded
# Report 60540V downloaded
# Report 16995Q downloaded
# Report 19323F downloaded
# Report 64310B downloaded
# Report 70720G downloaded
# Report 64630T downloaded
# Report 62090D downloaded
# Report 91371B downloaded
# Report 76060U downloaded
# Report 14008S downloaded
# Report 76082H downloaded
# Report 62570R downloaded
# Report 17045Q downloaded
# Report 15143G downloaded
# Report 19946S downloaded
# Report 60383I downloaded
# Report 16334S downloaded
# Report 18287W downloaded
# Report 68121S downloaded
# Report 20247W downloaded
# Report 14622N downloaded
# Report 18571T downloaded
# Report 20040A downloaded
# Report 15208I downloaded
# Report 19280N downloaded
# Report 19492F downloaded
# Report 19515O downloaded
# Report 19719H downloaded
# Report 60120W downloaded
# Report 63160D downloaded
# Report 15962T downloaded
# Report 17913Q downloaded
# Report 20346B downloaded
# Report 17915U downloaded
# Report 17553M downloaded
# Report 07191V downloaded
# Report 20421M downloaded
# Report 09238I downloaded
# Report 60250M downloaded
# Report 18118W downloaded
# Report 70350W downloaded
# Report 01867W downloaded
# Report 13459A downloaded
# Report 62000W downloaded
# Report 18294T downloaded
# Report 20384J downloaded
# Report 70650L downloaded
# Report 16961W downloaded
# Report 17823P downloaded
# Report 20274C downloaded
# Report 61680T downloaded
# Report 20143K downloaded
# Report 63550Q downloaded
# Report 19619D downloaded
# Report 70140L downloaded
# Report 14164J downloaded
# Report 64640W downloaded
# Report 18408I downloaded
# Report 19582G downloaded
# Report 18768P downloaded
# Report 20452A downloaded
# Report 17087J downloaded
# Report 17214N downloaded
# Report 70910L downloaded
# Report 19625V downloaded
# Report 20398U downloaded
# Report 70150O downloaded
# Report 11976K downloaded
# Report 17761T downloaded
# Report 18431D downloaded
# Report 00984V downloaded
# Report 72560U downloaded
# Report 71320S downloaded
# Report 16304J downloaded
# Report 60640C downloaded
# Report 91339F downloaded
# Report 72490C downloaded
# Report 19279F downloaded
# Report 18281K downloaded
# Report 70600T downloaded
# Report 76061W downloaded
# Report 60490J downloaded
# Report 01013N downloaded
# Report 70691C downloaded
# Report 17357M downloaded
# Report 13847J downloaded
# Report 63661C downloaded
# Report 64350N downloaded
# Report 70330Q downloaded
# Report 71310P downloaded
# Report 81014R downloaded
# Report 91436D downloaded
# Report 20181S downloaded
# Report 05508O downloaded
# Report 20389T downloaded
# Report 19455W downloaded
# Report 91502N downloaded
# Report 91516B downloaded
# Report 14180H downloaded
# Report 17523D downloaded
# Report 18681D downloaded
# Report 61220I downloaded
# Report 64240G downloaded
# Report 65170Q downloaded
# Report 81017A downloaded
# Report 91372D downloaded
# Report 60840K downloaded
# Report 71230R downloaded
# Report 63900R downloaded
# Report 19838P downloaded
# Report 18910P downloaded
# Report 12954F downloaded
# Report 20098I downloaded
# Report 61120E downloaded
# Report 62960H downloaded
# Report 19912B downloaded
# Report 60343T downloaded
# Report 19282R downloaded
# Report 20493O downloaded
# Report 72540O downloaded
# Report 17738B downloaded
# Report 19108B downloaded
# Report 81010J downloaded
# Report 17003A downloaded
# Report 19906G downloaded
# Report 65350S downloaded
# Report 61010U downloaded
# Report 91318U downloaded
# Report 70380I downloaded
# Report 76102K downloaded
# Report 91493P downloaded
# Report 13165G downloaded
# Report 14075K downloaded
# Report 14188A downloaded
# Report 18150S downloaded
# Report 20125I downloaded
# Report 62350D downloaded
# Report 91397T downloaded
# Report 02278I downloaded
# Report 06176U downloaded
# Report 19724A downloaded
# Report 71990R downloaded
# Report 91510M downloaded
# Report 64510J downloaded
# Report 64971W downloaded
# Report 76098W downloaded
# Report 19852J downloaded
# Report 20140E downloaded
# Report 64590K downloaded
# Report 20279M downloaded
# Report 60070K downloaded
# Report 62870G downloaded
# Report 19331E downloaded
# Report 70121H downloaded
# Report 16027J downloaded
# Report 19496N downloaded
# Report 16267G downloaded
# Report 19857T downloaded
# Report 20413N downloaded
# Report 20332N downloaded
# Report 12383L downloaded
# Report 16469S downloaded
# Report 18605K downloaded
# Report 72170H downloaded
# Report 18653V downloaded
# Report 62290L downloaded
# Report 17737W downloaded
# Report 64890W downloaded
# Report 19292U downloaded
# Report 19679V downloaded
# Report 60381E downloaded
# Report 71140Q downloaded
# Report 72100J downloaded
# Report 18788V downloaded
# Report 15140A downloaded
# Report 17993R downloaded
# Report 20304I downloaded
# Report 60090Q downloaded
# Report 62170B downloaded
# Report 62692I downloaded
# Report 64610N downloaded
# Report 14254K downloaded
# Report 70400L downloaded
# Report 19710M downloaded
# Report 19297H downloaded
# Report 14816D downloaded
# Report 19529C downloaded
# Report 20162O downloaded
# Report 01840C downloaded
# Report 15104T downloaded
# Report 18763F downloaded
# Report 19894C downloaded
# Report 07455G downloaded
# Report 13978B downloaded
# Report 17364J downloaded
# Report 17634M downloaded
# Report 19495L downloaded
# Report 20127M downloaded
# Report 76092K downloaded
# Report 19467G downloaded
# Report 65490L downloaded
# Report 12349L downloaded
# Report 10991B downloaded
# Report 11725I downloaded
# Report 14056G downloaded
# Report 91550B downloaded
# Report 15359G downloaded
# Report 16608G downloaded
# Report 19537B downloaded
# Report 70120F downloaded
# Report 70680U downloaded
# Report 76093M downloaded
# Report 19214A downloaded
# Report 62890M downloaded
# Report 63880O downloaded
# Report 70560K downloaded
# Report 61080S downloaded
# Report 01687U downloaded
# Report 17064U downloaded
# Report 17814O downloaded
# Report 18057F downloaded
# Report 60791A downloaded
# Report 64580H downloaded
# Report 71101G downloaded
# Report 71510A downloaded
# Report 14014N downloaded
# Report 17667E downloaded
# Report 65320J downloaded
# Report 18227E downloaded
# Report 19741A downloaded
# Report 64410F downloaded
# Report 20096E downloaded
# Report 19998O downloaded
# Report 76096S downloaded
# Report 18797W downloaded
# Report 19576L downloaded
# Report 63210P downloaded
# Report 20178G downloaded
# Report 17304O downloaded
# Report 63101K downloaded
# Report 11649S downloaded
# Report 14578N downloaded
# Report 16820E downloaded
# Report 17493U downloaded
# Report 20108I downloaded
# Report 17233R downloaded
# Report 11422N downloaded
# Report 13031I downloaded
# Report 64990D downloaded
# Report 64200R downloaded
# Report 91409A downloaded
# Report 13773G downloaded
# Report 19800N downloaded
# Report 20142I downloaded
# Report 14791N downloaded
# Report 15516T downloaded
# Report 76334I downloaded
# Report 18362K downloaded
# Report 60400F downloaded
# Report 16410I downloaded
# Report 17162U downloaded
# Report 18172F downloaded
# Report 20163Q downloaded
# Report 91496V downloaded
# Report 16118M downloaded
# Report 61560J downloaded
# Report 63270K downloaded
# Report 19696V downloaded
# Report 20191V downloaded
# Report 70141N downloaded
# Report 91315O downloaded
# Report 18381O downloaded
# Report 19661C downloaded
# Report 81012N downloaded
# Report 62830R downloaded
# Report 17188P downloaded
# Report 16143L downloaded
# Report 16471F downloaded
# Report 19927O downloaded
# Report 20432R downloaded
# Report 60420L downloaded
# Report 09938N downloaded
# Report 14866S downloaded
# Report 02670I downloaded
# Report 04469C downloaded
# Report 17827A downloaded
# Report 18646B downloaded
# Report 19432K downloaded
# Report 16821G downloaded
# Report 17218V downloaded
# Report 61910K downloaded
# Report 76068N downloaded
# Report 61141M downloaded
# Report 63001G downloaded
# Report 19947U downloaded
# Report 81005Q downloaded
# Report 17318C downloaded
# Report 01285A downloaded
# Report 20311F downloaded
# Report 20491K downloaded
# Report 13262E downloaded
# Report 18370J downloaded
# Report 15644F downloaded
# Report 16237U downloaded
# Report 17628R downloaded
# Report 72330D downloaded
# Report 20167B downloaded
# Report 61410N downloaded
# Report 63070C downloaded
# Report 63630O downloaded
# Report 19909M downloaded
# Report 70042L downloaded
# Report 72430H downloaded
# Report 91336W downloaded
# Report 91504R downloaded
# Report 60530S downloaded
# Report 91325R downloaded
# Report 09184L downloaded
# Report 63850F downloaded
# Report 91388S downloaded
# Report 91492N downloaded
# Report 14320U downloaded
# Report 17110B downloaded
# Report 19518U downloaded
# Report 19765O downloaded
# Report 19503H downloaded
# Report 20351R downloaded
# Report 13663W downloaded
# Report 71123Q downloaded
# Report 16136O downloaded
# Report 19325J downloaded
# Report 16461C downloaded
# Report 61930Q downloaded
# Report 62180E downloaded
# Report 76073G downloaded
# Report 81002K downloaded
# Report 19872P downloaded
# Report 65080P downloaded
# Report 11583O downloaded
# Report 18766L downloaded
# Report 10014Q downloaded
# Report 06658P downloaded
# Report 14925I downloaded
# Report 15523Q downloaded
# Report 16435B downloaded
# Report 17957N downloaded
# Report 19305D downloaded
# Report 62380M downloaded
# Report 70540E downloaded
# Report 72050U downloaded
# Report 72420E downloaded
# Report 91499E downloaded
# Report 76081F downloaded
# Report 16921K downloaded
# Report 17639W downloaded
# Report 19760E downloaded
# Report 19913D downloaded
# Report 63100I downloaded
# Report 65582Q downloaded
# Report 68068R downloaded
# Report 91515W downloaded
# Report 10120P downloaded
# Report 20179I downloaded
# Report 13621G downloaded
# Report 17324U downloaded
# Report 19635B downloaded
# Report 62061T downloaded
# Report 60851P downloaded
# Report 07949I downloaded
# Report 60261R downloaded
# Report 08379V downloaded
# Report 15796F downloaded
# Report 20231H downloaded
# Report 65180T downloaded
# Report 17747C downloaded
# Report 60380C downloaded
# Report 70960D downloaded
# Report 70830N downloaded
# Report 91462E downloaded
# Report 18791K downloaded
# Report 19207D downloaded
# Report 76085N downloaded
# Report 20281W downloaded
# Report 61790D downloaded
# Report 62880J downloaded
# Report 64691Q downloaded
# Report 76106S downloaded
# Report 16879O downloaded
# Report 17625L downloaded
# Report 18003F downloaded
# Report 18042P downloaded
# Report 18767N downloaded
# Report 19919P downloaded
# Report 20068W downloaded
# Report 65010R downloaded
# Report 14193Q downloaded
# Report 17563P downloaded
# Report 20078C downloaded
# Report 16276H downloaded
# Report 18391R downloaded
# Report 72530L downloaded
# Report 17759J downloaded
# Report 60550B downloaded
# Report 70440A downloaded
# Report 71450I downloaded
# Report 12633I downloaded
# Report 19630O downloaded
# Report 20160K downloaded
# Report 20259G downloaded
# Report 64820B downloaded
# Report 20055N downloaded
# Report 20043G downloaded
# Report 18037W downloaded
# Report 60361V downloaded
# Report 91505T downloaded
# Report 17574U downloaded
# Report 16930L downloaded
# Report 19991A downloaded
# Report 19545A downloaded
# Report 19779C downloaded
# Report 18298E downloaded
# Report 20381D downloaded
# Report 76130P downloaded
# Report 17217T downloaded
# Report 18193N downloaded
# Report 14468G downloaded
# Report 17129W downloaded
# Report 12180U downloaded
# Report 18563U downloaded
# Report 61320M downloaded
# Report 60720A downloaded
# Report 14830U downloaded
# Report 18125T downloaded
# Report 20292E downloaded
# Report 70500P downloaded
# Report 19151C downloaded
# Report 19636D downloaded
# Report 76090G downloaded
# Report 19841E downloaded
# Report 71220O downloaded
# Report 71280J downloaded
# Report 61940T downloaded
# Report 91412M downloaded
# Report 15285D downloaded
# Report 17602W downloaded
# Report 20028K downloaded
# Report 18288B downloaded
# Report 19470S downloaded
# Report 68077S downloaded
# Report 17505B downloaded
# Report 17710C downloaded
# Report 19410A downloaded
# Report 60820E downloaded
# Report 70610W downloaded
# Report 70410O downloaded
# Report 18483W downloaded
# Report 19294B downloaded
# Report 18038B downloaded
# Report 17260U downloaded
# Report 19373U downloaded
# Report 61690W downloaded
# Report 71570S downloaded
# Report 71960I downloaded
# Report 10653E downloaded
# Report 13047A downloaded
# Report 17167H downloaded
# Report 17336E downloaded
# Report 07900B downloaded
# Report 13026P downloaded
# Report 17200C downloaded
# Report 17726R downloaded
# Report 62210K downloaded
# Report 15408Q downloaded
# Report 17890H downloaded
# Report 20172R downloaded
# Report 10801Q downloaded
# Report 17093E downloaded
# Report 05144C downloaded
# Report 18630J downloaded
# Report 20371A downloaded
# Report 20465J downloaded
# Report 08512U downloaded
# Report 09927I downloaded
# Report 14586M downloaded
# Report 17903N downloaded
# Report 14651U downloaded
# Report 17447N downloaded
# Report 60510M downloaded
# Report 14231V downloaded
# Report 12631E downloaded
# Report 18260C downloaded
# Report 91332O downloaded
# Report 14909K downloaded
# Report 19350I downloaded
# Report 60750J downloaded
# Report 62440E downloaded
# Report 18968A downloaded
# Report 19009W downloaded
# Report 20079E downloaded
# Report 60491L downloaded
# Report 07441S downloaded
# Report 09353I downloaded
# Report 19478L downloaded
# Report 19354Q downloaded
# Report 20272V downloaded
# Report 01356U downloaded
# Report 01676P downloaded
# Report 19316I downloaded
# Report 20017F downloaded
# Report 71050P downloaded
# Report 18832V downloaded
# Report 62470N downloaded
# Report 19285A downloaded
# Report 61860V downloaded
# Report 71300M downloaded
# Report 76150V downloaded
# Report 18779U downloaded
# Report 91503P downloaded
# Report 15769C downloaded
# Report 20394M downloaded
# Report 19676P downloaded
# Report 18411U downloaded
# Report 18484B downloaded
# Report 15154L downloaded
# Report 72450N downloaded
# Report 62980N downloaded
# Report 60843Q downloaded
# Report 60342R downloaded
# Report 91426A downloaded
# Report 65241N downloaded
# Report 18514H downloaded
# Report 70740M downloaded
# Report 20275E downloaded
# Report 71150T downloaded
# Report 05253H downloaded
# Report 71840V downloaded
# Report 20289P downloaded
# Report 08419H downloaded
# Report 17108O downloaded
# Report 60841M downloaded
# Report 18021H downloaded
# Report 04005G downloaded
# Report 19442N downloaded
# Report 13876Q downloaded
# Report 12574S downloaded
# Report 71241W downloaded
# Report 18977B downloaded
# Report 14903V downloaded
# Report 19853L downloaded
# Report 61150N downloaded
# Report 91506V downloaded
# Report 19678T downloaded
# Report 12448N downloaded
# Report 18205R downloaded
# Report 65630B downloaded
# Report 61682A downloaded
# Report 13512B downloaded
# Report 15157R downloaded
# Report 18089S downloaded
# Report 76078Q downloaded
# Report 60390F downloaded
# Report 16384K downloaded
# Report 19624T downloaded
# Report 20352T downloaded
# Report 19039I downloaded
# Report 20269J downloaded
# Report 07442U downloaded
# Report 17652O downloaded
# Report 81008W downloaded
# Report 13643Q downloaded
# Report 18166K downloaded
# Report 18748J downloaded
# Report 01086R downloaded
# Report 16817P downloaded
# Report 68072I downloaded
# Report 17031F downloaded
# Report 71102I  downloaded
# Report 20182U downloaded
# Report 91491L downloaded
# Report 18233W downloaded
# Report 19907I downloaded
# Report 16841M downloaded
# Report 19225F downloaded
# Report 70710D downloaded
# Report 19566I downloaded
# Report 62310O downloaded
# Report 64130W downloaded
# Report 91390F downloaded
# Report 17079K downloaded
# Report 17212J downloaded
# Report 19851H downloaded
# Report 16249E downloaded
# Report 19409P downloaded
# Report 20338C downloaded
# Report 17734Q downloaded
# Report 18336J downloaded
# Report 70900I downloaded
# Report 12003V downloaded
# Report 17838F downloaded
# Report 13659I downloaded
# Report 76072E downloaded
# Report 91305L downloaded
# Report 19755L downloaded
# Report 16409A downloaded
# Report 19920A downloaded
# Report 14898I downloaded
# Report 18703K downloaded
# Report 15056L downloaded
# Report 76104O downloaded
# Report 76083J downloaded
# Report 91342R downloaded
# Report 71680C downloaded
# Report 76129H downloaded
# Report 17150N downloaded
# Report 15315J downloaded
# Report 20042E downloaded
# Report 71270G downloaded
# Report 19924I downloaded
# Report 19828M downloaded
# Report 17184H downloaded
# Report 11969N downloaded
# Report 17912O downloaded
# Report 64450R downloaded
# Report 63841E downloaded
# Report 70390L downloaded
# Report 18795S downloaded
# Report 91400F downloaded
# Report 20380B downloaded
# Report 19925K downloaded
# Report 20086B downloaded
# Report 19690J downloaded
# Report 13328I downloaded
# Report 20387P downloaded
# Report 12368P downloaded
# Report 14107U downloaded
# Report 62630J downloaded
# Report 19383A downloaded
# Report 91310E downloaded
# Report 20214H downloaded
# Report 71600B downloaded
# Report 71750U downloaded
# Report 19434O downloaded
# Report 71950F downloaded
# Report 16683U downloaded
# Report 70970G downloaded
# Report 61520U downloaded
# Report 65150K downloaded
# Report 20273A downloaded
# Report 18542M downloaded
# Report 16311G downloaded
# Report 72280O downloaded
# Report 20151J downloaded
# Report 19813W downloaded
# Report 18344I downloaded
# Report 00779U downloaded
# Report 18642Q downloaded
# Report 17606H downloaded
# Report 19272O downloaded
# Report 76103M downloaded
# Report 16092U downloaded
# Report 16345A downloaded
# Report 19893A downloaded
# Report 12613C downloaded
# Report 12741L downloaded
# Report 02124E downloaded
# Report 13752V downloaded
# Report 18590A downloaded
# Report 19267V downloaded
# Report 17159I downloaded
# Report 12358M downloaded
# Report 17742P downloaded
# Report 17104G downloaded
# Report 19831B downloaded
# Report 60140F downloaded
# Report 62900M downloaded
# Report 17189R downloaded
# Report 17808T downloaded
# Report 18217B downloaded
# Report 14000C downloaded
# Report 17620B downloaded
# Report 18759O downloaded
# Report 14767Q downloaded
# Report 17790D downloaded
# Report 07117J downloaded
# Report 18077L downloaded
# Report 16333Q downloaded
# Report 18347O downloaded
# Report 18482U downloaded
# Report 17732M downloaded
# Report 18473T downloaded
# Report 18421A downloaded
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-27ed9dce4be7> in <module>
#       5     PDFToConvert.append('Reports\\' + row['School Roll No.'] + '_' + row['Date'])
#       6     print('Report ' + row['School Roll No.'] + ' downloaded')
# ----> 7     wget.download(DownloadURL, FileName)
#
# ~/.pyenv/versions/3.7.7/envs/IIPE/lib/python3.7/site-packages/wget.py in download(url, out, bar)
#     524     else:
#     525         binurl = url
# --> 526     (tmpfile, headers) = ulib.urlretrieve(binurl, tmpfile, callback)
#     527     filename = detect_filename(url, out, headers)
#     528     if outdir:
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     523             req = meth(req)
#     524
# --> 525         response = self._open(req, data)
#     526
#     527         # post-process response
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/urllib/request.py in _open(self, req, data)
#     541         protocol = req.type
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#     545             return result
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/urllib/request.py in https_open(self, req)
#    1360         def https_open(self, req):
#    1361             return self.do_open(http.client.HTTPSConnection, req,
# -> 1362                 context=self._context, check_hostname=self._check_hostname)
#    1363
#    1364         https_request = AbstractHTTPHandler.do_request_
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1317             try:
#    1318                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1319                           encode_chunked=req.has_header('Transfer-encoding'))
#    1320             except OSError as err: # timeout error
#    1321                 raise URLError(err)
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1250                 encode_chunked=False):
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#    1254     def _send_request(self, method, url, body, headers, encode_chunked):
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1296             # default charset of iso-8859-1.
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#    1300     def getresponse(self):
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1245         else:
#    1246             raise CannotSendHeader()
# -> 1247         self._send_output(message_body, encode_chunked=encode_chunked)
#    1248
#    1249     def request(self, method, url, body=None, headers={}, *,
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1024         msg = b"\r\n".join(self._buffer)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#    1028         if message_body is not None:
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/http/client.py in send(self, data)
#     964         if self.sock is None:
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#     968                 raise NotConnected()
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/http/client.py in connect(self)
#    1420
#    1421             self.sock = self._context.wrap_socket(self.sock,
# -> 1422                                                   server_hostname=server_hostname)
#    1423
#    1424     __all__.append("HTTPSConnection")
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     421             server_hostname=server_hostname,
#     422             context=self,
# --> 423             session=session
#     424         )
#     425
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#     868                         # non-blocking
#     869                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 870                     self.do_handshake()
#     871             except (OSError, ValueError):
#     872                 self.close()
#
# ~/.pyenv/versions/3.7.7/lib/python3.7/ssl.py in do_handshake(self, block)
#    1137             if timeout == 0.0 and block:
#    1138                 self.settimeout(None)
# -> 1139             self._sslobj.do_handshake()
#    1140         finally:
#    1141             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Converting the PDFs to text and cleaning them from unusefull content

# %%
ConvertionCategories = {"Properly processed":0, "Not in text format":0, "Cannot be processed":0}
FilesProperlyConverted = {}
FilesNotConverted = []
def find_2nd(string, substring):
    return string.find(substring, string.find(substring) + 1)
for PDF in PDFToConvert:
    try: 
        Text = extract_text(PDF + '.pdf')
        if len(Text)==0:
            ConvertionCategories["Not in text format"] = ConvertionCategories["Not in text format"] + 1
            print(PDF + ' is not in text format')
        else:
            ConvertionCategories["Properly processed"] = ConvertionCategories["Properly processed"] + 1
            Option1 = Text.find('WHOLE-SCHOOL EVALUATION – MANAGEMENT, LEADERSHIP AND LEARNING   Dates of inspection')
            if Option1 != -1:
                Text = Text[Option1:]
            Option2 = Text.find('WHOLE-SCHOOL EVALUATION – MANAGEMENT, LEADERSHIP AND LEARNING    Date of inspection')
            if Option2 != -1:
                Text = Text[Option2:]
            Option3 = Text.find('WHOLE-SCHOOL EVALUATION – MANAGEMENT, LEADERSHIP AND LEARNING  Dates of inspection')
            if Option3 != -1:
                Text = Text[Option3:]
            Option4 = Text.find('WHOLE-SCHOOL EVALUATION – MANAGEMENT, LEADERSHIP AND LEARNING Dates of inspection')
            if Option4 != -1:
                Text = Text[Option4:]
            Option5 = Text.find('Whole-School Evaluation – Management, Leadership and Learning Dates of inspection')
            if Option5 != -1:
                Text = Text[Option5:]
            Option6 = Text.find('Whole-School Evaluation Date of inspection')
            if Option6 != -1:
                Text = Text[Option6:]
            if Text.find('An Roinn') == 1:
                Text = Text[find_2nd(Text, 'Dates of inspection'):]
            Option7 = Text.find('THE INSPECTORATE’S QUALITY CONTINUUM')
            if Option7 != -1:
                Text = Text[:Option7 - 1]
            Option8 = Text.find('MEASTÓIREACHT SCOILE UILE – BAINISTÍOCHT, CEANNAIREACHT AGUS FOGHLAIM')
            if Option8 != -1:
                FilesNotConverted.append(PDF[8:])
                print('Report ' + PDF[8:] + ' could not be processed')
                continue
            FilesProperlyConverted[PDF] = {'Text': Text}
            with open("Reports\\Plain text\\" + PDF[8:] + ".txt", "w", errors="ignore") as output:
                output.write(str(Text))
            print('Report ' + PDF[8:] + ' properly processed')
    except (KeyError, UnicodeEncodeError):
        ConvertionCategories["Cannot be processed"] = ConvertionCategories["Cannot be processed"] + 1
        FilesNotConverted.append(PDF[8:])
        print('Report ' + PDF[8:] + ' could not be processed')
        continue

df_FilesProperlyConverted = pd.DataFrame.from_dict(FilesProperlyConverted, orient='index')

plt.bar(*zip(*ConvertionCategories.items()))
#plt.show()

General_InspectionReports['Key'] = General_InspectionReports['School Roll No.'] + '_' + General_InspectionReports['Date']
General_InspectionReports.to_csv(r'Reports\\InspectionReports.csv', index=False)
for p in range(len(FilesNotConverted)):
    General_InspectionReports.drop(General_InspectionReports[General_InspectionReports.Key == FilesNotConverted[p]].index, inplace=True)
General_InspectionReports.to_csv(r'Reports\\InspectionReports2.csv', index=False)
# Out:
# ------------------------------------------------------------------
# FileNotFoundError                Traceback (most recent call last)
# <ipython-input-14-4293e6dc4292> in <module>
#       6 for PDF in PDFToConvert:
#       7     try:
# ----> 8         Text = extract_text(PDF + '.pdf')
#       9         if len(Text)==0:
#      10             ConvertionCategories["Not in text format"] = ConvertionCategories["Not in text format"] + 1
#
# ~/.pyenv/versions/3.7.7/envs/IIPE/lib/python3.7/site-packages/pdfminer/high_level.py in extract_text(pdf_file, password, page_numbers, maxpages, caching, codec, laparams)
#     106         laparams = LAParams()
#     107
# --> 108     with open_filename(pdf_file, "rb") as fp, StringIO() as output_string:
#     109         rsrcmgr = PDFResourceManager(caching=caching)
#     110         device = TextConverter(rsrcmgr, output_string, codec=codec,
#
# ~/.pyenv/versions/3.7.7/envs/IIPE/lib/python3.7/site-packages/pdfminer/utils.py in __init__(self, filename, *args, **kwargs)
#      24             filename = str(filename)
#      25         if isinstance(filename, str):
# ---> 26             self.file_handler = open(filename, *args, **kwargs)
#      27             self.closing = True
#      28         elif isinstance(filename, io.IOBase):
#
# FileNotFoundError: [Errno 2] No such file or directory: 'Reports\\70660O_27_01_2021.pdf'

# %% [markdown]
# ### Most used words

# %%
import matplotlib.pyplot as plt
import nltk, re
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.stem import WordNetLemmatizer
from collections import Counter
stopwords = set(nltk.corpus.stopwords.words('english'))

TotalText = []
for index, row in df_FilesProperlyConverted.iterrows():
    text = row['Text']
    TotalText.append(text)

newStopWords = ['school','learning','student','pupil','teacher','management','teaching','support', 'lesson', 'board']
stopwords = stopwords.union(newStopWords)
TotalText = " ".join(TotalText)
tokens = [w for w in word_tokenize(TotalText.lower()) if w.isalpha()]          # isalpha() checks if each word is alphabetical, lower() transforms everything to lowercase
no_stop = [t.strip() for t in tokens if t.strip() not in stopwords]      # stopwords already comes with a built-in list of words to remove
wordnet_lemmatizer = WordNetLemmatizer()
lemmatized = [wordnet_lemmatizer.lemmatize(t) for t in no_stop]
bow = Counter(lemmatized)
MostCommon = dict(bow.most_common(10))

plt.bar(*zip(*MostCommon.items()))
plt.title('Whole sample')
plt.xlabel('Most common words')
plt.ylabel('Number of times the word appears')
plt.xticks(rotation='vertical')
plt.savefig("Results\\Word count\\Whole sample.png")
plt.show()

# %% [markdown]
# ## Topic modelling

# %%
install.packages("readtext")
install.packages("stm")
install.packages("tm")
install.packages("SnowballC")
install.packages("igraph")

library(readtext)
library(stm)
library(tm)

# %%
setwd("C:\\Users\\g.vargas\\BOX\\IIEP_MyProjects\\MP_01000298\\WorkFiles_Inspection\\Ireland")
DATA_DIR <- system.file("extdata/", package = "readtext")
ourdata<-readtext("Reports\\Plain text\\*")
# Import additional metadata (year, language, etc.)
metadata <-read.csv("Reports\\InspectionReports.csv")

# %%
# Stemming and tokenization
NewStopWords <- c('school','learning','student','pupil', 'pupils','teacher','management','teaching','support', 'lesson', 'board')
processed_data <- textProcessor(ourdata$text,  customstopwords=NewStopWords)

# Prepare Documents For Analysis With Stm
prepared_data <- prepDocuments(processed_data$documents, processed_data$vocab, processed_data$meta)
# Once the prepared_data is ready, open it, see where the metadata is located, and add the information from the ourmetadata

# %%
# STM MODELING
# The number of topics can be automatically determined using searchK (see https://cbail.github.io/SICSS_Topic_Modeling.html)
# max.em.its is how many times the model should run
poliblogPrevFit <- stm(prepared_data$documents, prepared_data$vocab, K=3, max.em.its=30, 
                       data=prepared_data$meta, init.type="Spectral")

# %%
png(filename="Results\\Topic modelling\\Two topics word comparison.png", 
    type="cairo",
    units="in", 
    width=10, 
    height=8, 
    pointsize=12, 
    res=300)
plot(poliblogPrevFit, type="perspectives", topics=c(1,2))
dev.off()

# %%
png(filename="Results\\Topic modelling\\Topic prevalence.png", 
    type="cairo",
    units="in", 
    width=10, 
    height=8, 
    pointsize=12, 
    res=300)
plot(poliblogPrevFit, type="summary", xlim=c(0,.8))
dev.off()

# %%
png(filename="Results\\Topic modelling\\Words from selected topics.png", 
    type="cairo",
    units="in", 
    width=10, 
    height=8, 
    pointsize=12, 
    res=300)
plot(poliblogPrevFit, type="labels", topics=c(1,2,3))
dev.off()

# %%
png(filename="Results\\Topic modelling\\Distribution Document Topic Proportions.png", 
    type="cairo",
    units="in", 
    width=10, 
    height=8, 
    pointsize=12, 
    res=300)
plot(poliblogPrevFit, type="hist")
dev.off()

# %%
topic_correlation <- topicCorr(poliblogPrevFit, method = c("simple", "huge"), cutoff = 0.01,
                               verbose = TRUE)

plot(topic_correlation, topics = NULL, vlabels = NULL, layout = NULL,
     vertex.color = "green", vertex.label.cex = 0.75,
     vertex.label.color = "black")
