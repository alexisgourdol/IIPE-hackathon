# %% [markdown]
# # Topic modelling from Ireland schools inspection reports

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import os
from nltk.corpus import stopwords 
import string
from nltk.stem.wordnet import WordNetLemmatizer
from nltk import word_tokenize
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# %% [markdown]
# ## text preprocessing function

# %%
def clean(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, ' ') # Remove Punctuation
    lowercased = text.lower() # Lower Case
    tokenized = word_tokenize(lowercased) # Tokenize
    words_only = [word for word in tokenized if word.isalpha()] # Remove numbers
    stop = set(stopwords.words('english')) # Make stopword list
    
    newStopWords = set(['school','schools','learning','student','students','pupil','pupils','teacher','teachers','management','managements','teaching','support','suppports', 'lesson','lessons','boards', 'board'])
    stop = stop.union(newStopWords)
 
    without_stopwords = [word for word in words_only if word not in stop] # Remove Stop Words
    
    lemma=WordNetLemmatizer() # Initiate Lemmatizer
    lemmatized = [lemma.lemmatize(word) for word in without_stopwords] # Lemmatize
   
    return lemmatized

# %% [markdown]
# ## from PDF to raw text

# %% [markdown]
# ## starting with a small sample of 5 texts from 5 PDFs

# %%
list_sample = os.listdir('../../IIPE-data/IIPE/data_sample/plain_text_sample')
list_sample = [file for file in list_sample if file[-4:] == '.txt']
list_sample
# Out:
# ['Reports_Plain text_05933G_08_10_2020.txt',
#  'Reports_Plain text_03220F_15_11_2019.txt',
#  'Reports_Plain text_07518E_15_12_2020.txt',
#  'Reports_Plain text_03917V_23_09_2020.txt',
#  'Reports_Plain text_01300Q_08_10_2020.txt']

# %% [markdown]
# ## putting the text into a DataFrame

# %%
cols , dfs = [], []
for file in list_sample:
    cols.append('../../IIPE-data/IIPE/data_sample/plain_text_sample/'+file)
for file in list_sample:
    dfs.append(pd.read_csv('../../IIPE-data/IIPE/data_sample/plain_text_sample/'+file,header=None,sep='\t',))
    
sample_df = pd.concat(dfs,)
sample_df.reset_index(inplace=True)   
sample_df.drop(columns='index',inplace=True)
sample_df.rename(columns={0:'text'},inplace=True)
sample_df
# Out:
#                                                 text
# 0  Whole-School Evaluation – Management, Leadersh...
# 1  Whole-School Evaluation – Management, Leadersh...
# 2  Whole-School Evaluation – Management, Leadersh...
# 3  Whole-School Evaluation – Management, Leadersh...
# 4  Whole-School Evaluation – Management, Leadersh...

# %% [markdown]
# ## preprocessing the text

# %%
# Apply to all texts
sample_df['clean_text'] = sample_df['text'].apply(clean)

sample_df.drop(columns='text',inplace=True)

sample_df.head()
# Out:
#                                           clean_text
# 0  [whole, evaluation, leadership, date, inspecti...
# 1  [whole, evaluation, leadership, date, inspecti...
# 2  [whole, evaluation, leadership, date, inspecti...
# 3  [whole, evaluation, leadership, date, inspecti...
# 4  [whole, evaluation, leadership, date, inspecti...

# %%
sample_df.clean_text[0]
# Out:
# ['whole',
#  'evaluation',
#  'leadership',
#  'date',
#  'inspection',
#  'inspection',
#  'activity',
#  'undertaken',
#  'meeting',
#  'principal',
#  'leadership',
#  'team',
#  'meeting',
#  'representative',
#  'meeting',
#  'parent',
#  'representative',
#  'meeting',
#  'review',
#  'relevant',
#  'document',
#  'analysis',
#  'parent',
#  'questionnaire',
#  'observation',
#  'examination',
#  'work',
#  'interaction',
#  'feedback',
#  'principal',
#  'deputy',
#  'principal',
#  'parent',
#  'representative',
#  'context',
#  'presentation',
#  'primary',
#  'george',
#  'hill',
#  'located',
#  'dublin',
#  'caters',
#  'boy',
#  'infant',
#  'first',
#  'class',
#  'girl',
#  'infant',
#  'sixth',
#  'class',
#  'operates',
#  'patronage',
#  'catholic',
#  'archbishop',
#  'dublin',
#  'participates',
#  'band',
#  'delivering',
#  'equality',
#  'opportunity',
#  'deis',
#  'action',
#  'plan',
#  'department',
#  'education',
#  'skill',
#  'educational',
#  'inclusion',
#  'time',
#  'evaluation',
#  'enrolled',
#  'overall',
#  'attendance',
#  'rate',
#  'good',
#  'actively',
#  'addressing',
#  'improvement',
#  'experienced',
#  'significant',
#  'turnover',
#  'staff',
#  'recent',
#  'year',
#  'current',
#  'staffing',
#  'includes',
#  'administrative',
#  'principal',
#  'eight',
#  'mainstream',
#  'class',
#  'four',
#  'special',
#  'educational',
#  'need',
#  'sen',
#  'access',
#  'home',
#  'community',
#  'liaison',
#  'hscl',
#  'co',
#  'ordinator',
#  'shared',
#  'another',
#  'summary',
#  'main',
#  'finding',
#  'recommendation',
#  'finding',
#  'overall',
#  'quality',
#  'good',
#  'demonstrate',
#  'commendable',
#  'disposition',
#  'high',
#  'level',
#  'engagement',
#  'outcome',
#  'improving',
#  'quality',
#  'good',
#  'overall',
#  'aspect',
#  'practice',
#  'observed',
#  'ranged',
#  'fair',
#  'highly',
#  'commendable',
#  'aspect',
#  'provision',
#  'sen',
#  'effective',
#  'inconsistency',
#  'implementation',
#  'continuum',
#  'mainstream',
#  'setting',
#  'instance',
#  'multiplicity',
#  'support',
#  'provided',
#  'impact',
#  'adversely',
#  'cohesiveness',
#  'experience',
#  'wellbeing',
#  'good',
#  'whole',
#  'approach',
#  'behaviour',
#  'impacting',
#  'positively',
#  'capacity',
#  'engage',
#  'also',
#  'enriching',
#  'personal',
#  'wellbeing',
#  'overall',
#  'quality',
#  'leadership',
#  'good',
#  'suitable',
#  'structure',
#  'recently',
#  'established',
#  'contribute',
#  'smooth',
#  'running',
#  'purposeful',
#  'leadership',
#  'distributed',
#  'model',
#  'leadership',
#  'early',
#  'stage',
#  'development',
#  'opportunity',
#  'remain',
#  'whole',
#  'engagement',
#  'progressing',
#  'quality',
#  'self',
#  'evaluation',
#  'good',
#  'used',
#  'continued',
#  'professional',
#  'development',
#  'cpd',
#  'purposefully',
#  'improvement',
#  'initiative',
#  'recommendation',
#  'coordination',
#  'provision',
#  'sen',
#  'reviewed',
#  'ensure',
#  'cohesive',
#  'experience',
#  'optimise',
#  'sen',
#  'extend',
#  'good',
#  'practice',
#  'pertaining',
#  'continuum',
#  'noted',
#  'setting',
#  'mainstream',
#  'setting',
#  'greater',
#  'emphasis',
#  'placed',
#  'delineation',
#  'leadership',
#  'role',
#  'responsibility',
#  'view',
#  'extending',
#  'observed',
#  'example',
#  'highly',
#  'effective',
#  'practice',
#  'whole',
#  'basis',
#  'detailed',
#  'finding',
#  'recommendation',
#  'quality',
#  'overall',
#  'quality',
#  'good',
#  'demonstrate',
#  'commendable',
#  'disposition',
#  'high',
#  'level',
#  'engagement',
#  'outcome',
#  'improving',
#  'recite',
#  'poem',
#  'rhyme',
#  'sing',
#  'song',
#  'enthusiasm',
#  'questionnaire',
#  'response',
#  'reported',
#  'enjoy',
#  'recall',
#  'make',
#  'connection',
#  'confidently',
#  'communicate',
#  'competently',
#  'english',
#  'irish',
#  'mathematics',
#  'vocabulary',
#  'developed',
#  'well',
#  'many',
#  'opportunity',
#  'provided',
#  'use',
#  'new',
#  'vocabulary',
#  'context',
#  'english',
#  'mathematics',
#  'greater',
#  'scope',
#  'exists',
#  'practise',
#  'use',
#  'vocabulary',
#  'context',
#  'irish',
#  'commendably',
#  'observed',
#  'reading',
#  'suitable',
#  'expression',
#  'fluency',
#  'sample',
#  'writing',
#  'indicate',
#  'write',
#  'well',
#  'range',
#  'genre',
#  'variety',
#  'reason',
#  'potential',
#  'across',
#  'transfer',
#  'skill',
#  'acquired',
#  'english',
#  'ensure',
#  'orally',
#  'present',
#  'independently',
#  'record',
#  'new',
#  'across',
#  'area',
#  'curriculum',
#  'enabled',
#  'set',
#  'achieve',
#  'meaningful',
#  'personal',
#  'goal',
#  'result',
#  'engagement',
#  'programme',
#  'social',
#  'emotional',
#  'need',
#  'enjoy',
#  'wide',
#  'variety',
#  'valuable',
#  'experience',
#  'regular',
#  'opportunity',
#  'active',
#  'ample',
#  'opportunity',
#  'many',
#  'setting',
#  'use',
#  'digital',
#  'technology',
#  'provided',
#  'evaluation',
#  'effective',
#  'use',
#  'resource',
#  'game',
#  'project',
#  'work',
#  'particularly',
#  'social',
#  'environmental',
#  'scientific',
#  'education',
#  'noted',
#  'supported',
#  'celebrated',
#  'infant',
#  'class',
#  'regular',
#  'opportunity',
#  'engage',
#  'play',
#  'based',
#  'integrated',
#  'thematic',
#  'effective',
#  'language',
#  'experience',
#  'display',
#  'observed',
#  'majority',
#  'setting',
#  'opportunity',
#  'work',
#  'collaboratively',
#  'observed',
#  'setting',
#  'noted',
#  'good',
#  'facilitated',
#  'work',
#  'collaboratively',
#  'open',
#  'ended',
#  'skill',
#  'based',
#  'investigative',
#  'activity',
#  'allowed',
#  'use',
#  'language',
#  'purposefully',
#  'deepen',
#  'comprehension',
#  'practice',
#  'resulted',
#  'successful',
#  'outcome',
#  'extended',
#  'setting',
#  'used',
#  'plan',
#  'language',
#  'rich',
#  'across',
#  'curriculum',
#  'analysis',
#  'questionnaire',
#  'data',
#  'submitted',
#  'parent',
#  'indicates',
#  'almost',
#  'parent',
#  'happy',
#  'parent',
#  'agreed',
#  'strongly',
#  'agreed',
#  'child',
#  'enjoys',
#  'quality',
#  'quality',
#  'good',
#  'overall',
#  'aspect',
#  'practice',
#  'observed',
#  'ranged',
#  'fair',
#  'highly',
#  'commendable',
#  'create',
#  'positive',
#  'atmosphere',
#  'characterised',
#  'mutual',
#  'respect',
#  'positive',
#  'affirmation',
#  'quality',
#  'practice',
#  'good',
#  'closely',
#  'aligned',
#  'varying',
#  'need',
#  'high',
#  'expectation',
#  'together',
#  'effective',
#  'pacing',
#  'opportunity',
#  'collaborate',
#  'consolidation',
#  'understanding',
#  'quality',
#  'characterise',
#  'quality',
#  'le',
#  'effective',
#  'approach',
#  'fully',
#  'meet',
#  'need',
#  'emphasis',
#  'directed',
#  'task',
#  'objective',
#  'unclear',
#  'weakness',
#  'addressed',
#  'leadership',
#  'ensure',
#  'consistency',
#  'practice',
#  'across',
#  'demonstrated',
#  'successful',
#  'classroom',
#  'skill',
#  'behaviour',
#  'good',
#  'evaluation',
#  'highly',
#  'respectful',
#  'interaction',
#  'observed',
#  'across',
#  'aspect',
#  'provision',
#  'sen',
#  'effective',
#  'inconsistency',
#  'implementation',
#  'continuum',
#  'mainstream',
#  'setting',
#  'instance',
#  'multiplicity',
#  'support',
#  'provided',
#  'impact',
#  'adversely',
#  'cohesiveness',
#  'experience',
#  'minority',
#  'setting',
#  'target',
#  'plan',
#  'specific',
#  'measurable',
#  'time',
#  'bound',
#  'good',
#  'practice',
#  'extended',
#  'plan',
#  'ensure',
#  'maximum',
#  'sen',
#  'extend',
#  'good',
#  'practice',
#  'pertaining',
#  'continuum',
#  'noted',
#  'minority',
#  'setting',
#  'mainstream',
#  'setting',
#  'use',
#  'class',
#  'withdrawal',
#  'model',
#  'commended',
#  'engaging',
#  'continuing',
#  'professional',
#  'development',
#  'cpd',
#  'introduction',
#  'class',
#  'english',
#  'mathematics',
#  'class',
#  'aspect',
#  'class',
#  'clearly',
#  'defined',
#  'including',
#  'effective',
#  'use',
#  'evidence',
#  'based',
#  'intervention',
#  'literacy',
#  'lift',
#  'ready',
#  'set',
#  'go',
#  'math',
#  'improve',
#  'overall',
#  'quality',
#  'class',
#  'english',
#  'mathematics',
#  'procedure',
#  'established',
#  'ensure',
#  'greater',
#  'range',
#  'class',
#  'approach',
#  'based',
#  'prioritised',
#  'need',
#  'style',
#  'enable',
#  'devise',
#  'stimulating',
#  'differentiated',
#  'opportunity',
#  'provision',
#  'opportunity',
#  'challenge',
#  'cohort',
#  'also',
#  'advised',
#  'skilful',
#  'deployment',
#  'approach',
#  'also',
#  'holistic',
#  'development',
#  'greatest',
#  'level',
#  'need',
#  'including',
#  'skill',
#  'attitude',
#  'personal',
#  'social',
#  'need',
#  'enable',
#  'engage',
#  'highly',
#  'commendable',
#  'overall',
#  'quality',
#  'assessment',
#  'good',
#  'assessment',
#  'information',
#  'used',
#  'well',
#  'inform',
#  'model',
#  'class',
#  'good',
#  'practice',
#  'observed',
#  'underlying',
#  'purpose',
#  'approach',
#  'clearly',
#  'aligned',
#  'priority',
#  'need',
#  'experience',
#  'however',
#  'evident',
#  'setting',
#  'model',
#  'intervention',
#  'reviewed',
#  'ensure',
#  'underlying',
#  'purpose',
#  'approach',
#  'clearly',
#  'align',
#  'priority',
#  'need',
#  'experience',
#  'written',
#  'work',
#  'carefully',
#  'monitored',
#  'good',
#  'example',
#  'formative',
#  'feedback',
#  'noted',
#  'majority',
#  'setting',
#  'culture',
#  'collaboration',
#  'exists',
#  'among',
#  'staff',
#  'resulted',
#  'successful',
#  'implementation',
#  'improvement',
#  'initiative',
#  'engage',
#  'ongoing',
#  'professional',
#  'development',
#  'encouraged',
#  'use',
#  'training',
#  'purposefully',
#  'enhance',
#  'practice',
#  'individual',
#  'whole',
#  'basis',
#  'collaborative',
#  'planning',
#  'necessary',
#  'devising',
#  'progression',
#  'plan',
#  'cohort',
#  'quality',
#  'wellbeing',
#  'wellbeing',
#  'good',
#  'whole',
#  'approach',
#  'behaviour',
#  'impacting',
#  'positively',
#  'capacity',
#  'engage',
#  'personal',
#  'wellbeing',
#  'response',
#  'questionnaire',
#  'indicate',
#  'majority',
#  'feel',
#  'safe',
#  'class',
#  'almost',
#  'like',
#  'effective',
#  'example',
#  'fostering',
#  'social',
#  'emotional',
#  'wellbeing',
#  'observed',
#  'example',
#  'particularly',
#  'commendable',
#  'practice',
#  'also',
#  'evidence',
#  'promotes',
#  'inclusive',
#  'culture',
#  'welcome',
#  'diversity',
#  'proactive',
#  'seeking',
#  'providing',
#  'family',
#  'consideration',
#  'given',
#  'introduction',
#  'council',
#  'increasing',
#  'participation',
#  'activity',
#  'response',
#  'inspectorate',
#  'questionnaire',
#  'half',
#  'indicated',
#  'know',
#  'say',
#  'thing',
#  'done',
#  'response',
#  'inspectorate',
#  'questionnaire',
#  'parent',
#  'either',
#  'agree',
#  'strongly',
#  'agree',
#  'good',
#  'atmosphere',
#  'almost',
#  'parent',
#  'reported',
#  'welcome',
#  'home',
#  'community',
#  'liaison',
#  'co',
#  'ordinator',
#  'organises',
#  'wide',
#  'range',
#  'course',
#  'parent',
#  'working',
#  'actively',
#  'establish',
#  'parent',
#  'association',
#  'quality',
#  'leadership',
#  'overall',
#  'quality',
#  'leadership',
#  'good',
#  'suitable',
#  'structure',
#  'recently',
#  'established',
#  'contribute',
#  'smooth',
#  'running',
#  'purposeful',
#  'leadership',
#  'distributed',
#  'model',
#  'leadership',
#  'early',
#  'stage',
#  'development',
#  'opportunity',
#  'remain',
#  'whole',
#  'engagement',
#  'progressing',
#  'clear',
#  'understanding',
#  'role',
#  'demonstrates',
#  'strong',
#  'commitment',
#  'development',
#  'recently',
#  'appointed',
#  'principal',
#  'demonstrates',
#  'highly',
#  'effective',
#  'organisational',
#  'skill',
#  'since',
#  'appointment',
#  'judiciously',
#  'identified',
#  'addressed',
#  'number',
#  'priority',
#  'improvement',
#  'deputy',
#  'principal',
#  'carry',
#  'range',
#  'duty',
#  'competently',
#  'together',
#  'principal',
#  'deputy',
#  'principal',
#  'demonstrate',
#  'clear',
#  'understanding',
#  'change',
#  'process',
#  'approach',
#  'change',
#  'collaborative',
#  'flexible',
#  'sensitive',
#  'manner',
#  'leader',
#  'work',
#  'promote',
#  'culture',
#  'although',
#  'leadership',
#  'role',
#  'appointed',
#  'recently',
#  'action',
#  'resulting',
#  'positive',
#  'change',
#  'good',
#  'aspect',
#  'leadership',
#  'noted',
#  'greater',
#  'emphasis',
#  'placed',
#  'delineation',
#  'leadership',
#  'role',
#  'responsibility',
#  'view',
#  'extending',
#  'observed',
#  'example',
#  'highly',
#  'effective',
#  'practice',
#  'whole',
#  'basis',
#  'leadership',
#  'team',
#  'demonstrates',
#  'commendable',
#  'capacity',
#  'enable',
#  'leading',
#  'across',
#  'reported',
#  'open',
#  'providing',
#  'placement',
#  'engagement',
#  'initial',
#  'education',
#  'programme',
#  'welcome',
#  'included',
#  'among',
#  'council',
#  'code',
#  'professional',
#  'conduct',
#  'provide',
#  'valuable',
#  'professional',
#  'benefit',
#  'education',
#  'institute',
#  'quality',
#  'self',
#  'evaluation',
#  'quality',
#  'self',
#  'evaluation',
#  'good',
#  'used',
#  'deis',
#  'planning',
#  'process',
#  'develop',
#  'implement',
#  'various',
#  'initiative',
#  'literacy',
#  'numeracy',
#  'attendance',
#  'retention',
#  'partnership',
#  'parent',
#  'others',
#  'improvement',
#  'plan',
#  'clear',
#  'target',
#  'set',
#  'action',
#  'identified',
#  'parent',
#  'view',
#  'sought',
#  'part',
#  'sse',
#  'process',
#  'ensure',
#  'target',
#  'improvement',
#  'specific',
#  'linked',
#  'strong',
#  'baseline',
#  'data',
#  'system',
#  'regular',
#  'monitoring',
#  'implementation',
#  'effectiveness',
#  'new',
#  'initiative',
#  'developed',
#  'ensure',
#  'agreed',
#  'action',
#  'become',
#  'embedded',
#  'classroom',
#  'whole',
#  'practice',
#  'accessed',
#  'valuable',
#  'cpd',
#  'area',
#  'prioritised',
#  'development',
#  'positive',
#  'impact',
#  'outcome',
#  'experience',
#  'noted',
#  'appendix',
#  'response',
#  'report',
#  'submitted',
#  'part',
#  'observation',
#  'content',
#  'inspection',
#  'report',
#  'welcome',
#  'wse',
#  'mll',
#  'report',
#  'presentation',
#  'primary',
#  'george',
#  'hill',
#  'carried',
#  ...]

# %% [markdown]
# ## feature engineering?

# %% [markdown]
# ## vectorizing the data: TF-IDF

# %%
# the argument passed to the TF-IDF vectorizer must be a list of strings
corpus = []
for text_ in list(sample_df.clean_text):
    corpus.append(' '.join(text_))
corpus
# Out:
# ['whole evaluation leadership date inspection inspection activity undertaken meeting principal leadership team meeting representative meeting parent representative meeting review relevant document analysis parent questionnaire observation examination work interaction feedback principal deputy principal parent representative context presentation primary george hill located dublin caters boy infant first class girl infant sixth class operates patronage catholic archbishop dublin participates band delivering equality opportunity deis action plan department education skill educational inclusion time evaluation enrolled overall attendance rate good actively addressing improvement experienced significant turnover staff recent year current staffing includes administrative principal eight mainstream class four special educational need sen access home community liaison hscl co ordinator shared another summary main finding recommendation finding overall quality good demonstrate commendable disposition high level engagement outcome improving quality good overall aspect practice observed ranged fair highly commendable aspect provision sen effective inconsistency implementation continuum mainstream setting instance multiplicity support provided impact adversely cohesiveness experience wellbeing good whole approach behaviour impacting positively capacity engage also enriching personal wellbeing overall quality leadership good suitable structure recently established contribute smooth running purposeful leadership distributed model leadership early stage development opportunity remain whole engagement progressing quality self evaluation good used continued professional development cpd purposefully improvement initiative recommendation coordination provision sen reviewed ensure cohesive experience optimise sen extend good practice pertaining continuum noted setting mainstream setting greater emphasis placed delineation leadership role responsibility view extending observed example highly effective practice whole basis detailed finding recommendation quality overall quality good demonstrate commendable disposition high level engagement outcome improving recite poem rhyme sing song enthusiasm questionnaire response reported enjoy recall make connection confidently communicate competently english irish mathematics vocabulary developed well many opportunity provided use new vocabulary context english mathematics greater scope exists practise use vocabulary context irish commendably observed reading suitable expression fluency sample writing indicate write well range genre variety reason potential across transfer skill acquired english ensure orally present independently record new across area curriculum enabled set achieve meaningful personal goal result engagement programme social emotional need enjoy wide variety valuable experience regular opportunity active ample opportunity many setting use digital technology provided evaluation effective use resource game project work particularly social environmental scientific education noted supported celebrated infant class regular opportunity engage play based integrated thematic effective language experience display observed majority setting opportunity work collaboratively observed setting noted good facilitated work collaboratively open ended skill based investigative activity allowed use language purposefully deepen comprehension practice resulted successful outcome extended setting used plan language rich across curriculum analysis questionnaire data submitted parent indicates almost parent happy parent agreed strongly agreed child enjoys quality quality good overall aspect practice observed ranged fair highly commendable create positive atmosphere characterised mutual respect positive affirmation quality practice good closely aligned varying need high expectation together effective pacing opportunity collaborate consolidation understanding quality characterise quality le effective approach fully m ...
#  'whole evaluation leadership date inspection inspection activity undertaken meeting principal leadership team meeting representative meeting parent representative meeting review relevant document analysis parent questionnaire observation examination work interaction feedback principal deputy principal parent representative context mercy primary girl urban patronage catholic bishop killaloe administrative principal seven mainstream class four based special education including one special class one home community liaison hscl three externally based two special need assistant participates delivering equality opportunity deis action plan department education skill educational inclusion time evaluation girl enrolled summary main finding recommendation finding quality good scope develop use transfer skill across curricular area special educational need sen well supported target setting sufficiently aligned priority need high quality scope refinement assessment practice whole level well supported effectively atmosphere warm inclusive conducive quality leadership good principal foster collaborative culture promotes sharing good practice self evaluation sse process implemented effectively recommendation explore additional practice promote use skill set among encourage evaluate transfer across broader range context programme special educational need underpinned weekly planning incorporate specific measurable achievable target address priority need identified analysis assessment data whole collaborative approach strategic use assessment data developed data gathered used consistently planning differentiated outcome detailed finding recommendation quality quality good demonstrate positive attitude maintain balance input led given many opportunity work collaboratively independently supportive well resourced environment literacy numeracy skill progressed effective implementation whole intervention initiative tá na daltaí dearfach leith na gaeilge tá ngnóthachtáil sa teanga ó bhéal le moladh agus iad ábalta cumarsáid fhiúntach shimplí dhéanamh mar theanga bheo suímh fhoirmiúla agus neamhfhoirmiúla chun tógáil ar bhfoghlaim seo b fhiú deiseanna chruthú dóibh teanga ó bhéal úsáid mar bhunús obair scríofa agus tabhairt faoi réimse níos leithne seánraí scríbhneoireachta chomh maith positive attitude gaeilge oral competence praiseworthy able conduct basic meaningful conversation living language formal informal setting using skill basis improvement opportunity created develop written skill undertake wider range genre local environment community used effectively resource interest history heritage environment commendable progress acquisition instrumental musical skill engagement project work add enriching dimension noted however always make meaningful connection across curriculum beyond context use skill set acquired one area extended facilitated situation across beyond curriculum encouraged see relevance skill apply new activity special educational need supported effectively currently reviewing provision sen begun implement continuum practice evolves aim achieve balance class group individual intervention short term planning carried weekly basis specify development skill content address priority need based upon relevant assessment data target setting aligned priority need objective specific measurable used inform future planning quality create inclusive centred stimulating environment classroom excellent high expectation work behaviour communicate expectation effectively observed inspector evaluation characterised clear communication desired outcome high quality instruction skilful questioning concluded consolidation review use range methodology including focused pair group activity purposeful talk discussion provide active engaging dimension junior class social communication skill progressed appropriately supported play based experience oral language proficiency class developed consistently targeted exposure topic specific vocabulary across curric ...
#  'whole evaluation leadership date inspection inspection activity undertaken meeting principal leadership team meeting representative meeting parent representative meeting review relevant document analysis parent questionnaire observation examination work interaction feedback principal deputy principal parent representative evaluation paused due closure arising covid pandemic majority inspection activity took place march feedback meeting held october context scoil náisiúnta cnoc mharcaigh co educational primary patronage catholic bishop ardagh clonmacnoise administrative principal eleven mainstream class four special education time evaluation enrolled attendance level good overall summary main finding recommendation finding quality good overall displaying appropriate level content mastery across range subject communication skill irish underdeveloped quality good overall considerable variance approach developing self assessment skill identifying strength area development learner quality leadership good overall quality well good overall quality self evaluation sse good recommendation whole approach agreed implemented develop communication skill irish incrementally systematically adopt whole approach reflect consistent developmental manner detailed finding recommendation quality overall quality good demonstrate positive disposition towards display appropriate level content mastery across range subject display commendable ability apply knowledge relevant process mathematics social environmental scientific education variety appropriate context including real life situation inspectorate questionnaire agreed enjoy almost parent agreed child well experiment imaginative way range art material produce high quality creation visual art demonstrate keen awareness work various artist enjoy listening responding music enabled make music individually collaboratively engage percussion instrument demonstrate rhythm effectively lack incremental development knowledge musical literacy whole approach devised implemented progression area provided opportunity engage thematic integrated project work including engineering based open ended design make activity majority observed participation high standard provided opportunity collaborate demonstrate creativity whole emphasis use non reusable workbook reduced view making increased provision active engaging experience infant access broad range structured open ended material playful opportunity exist enhance language facilitating purposeful engagement socio dramatic play majority confident articulate communicator english good use subject specific vocabulary across broad range curricular area sa ghaeilge tá scileanna cumarsáide sásúil ag na daltaí tá siad ann abairtí simplí thuiscint agus úsáid ach téann sé dian orthu comhrá bheith acu go nadúrtha ba chóir cur chuige uile scoile aontú agus chur bhfeidhm chun scileanna cumarsáide na ndaltaí fhorbairt go céimniúil agus go córasach irish satisfactory communication skill able understand use simple sentence find difficult converse naturally whole approach agreed implemented develop communication skill incrementally systematically quality quality good overall engaged range continuous professional development course pedagogical knowledge developing overall good classroom skill create inclusive environment based mutual respect affirmation trust collective practice successful implementation whole approach writing genre comprehensive strategy english problem solving mathematics highly commendable overall majority observed appropriately structured paced purposeful opportunity apply consolidate good practice observed intention success criterion shared appropriate balance led input participation small number insufficient opportunity provided engage active collaborative place greater emphasis facilitating effective balance led support special education need delivered variety mode including withdrawal station class intervention programme work provided closely aligned prior ...
#  'whole evaluation leadership date inspection inspection activity undertaken meeting principal leadership team meeting representative meeting parent representative meeting review relevant document analysis parent questionnaire observation examination work interaction feedback principal deputy principal representative context naomh pádraig boy caters boy junior infant sixth class operates patronage catholic archbishop dublin participates delivering equality opportunity deis action plan department education skill educational inclusion enrolled currently attendance punctuality good staffing includes administrative principal seven mainstream four special educational need sen one part time based another service shared home community liaison co ordinator summary main finding recommendation finding managed effectively principal demonstrate well developed leadership skill good good methodology observed almost experience infant class high quality commendable attaining well english reading mathematics writing skill require development assessment effective overall although significant variation quality individual practice wellbeing good calm respectful environment self confidence nurtured self evaluation sse effective deis planning impact positively specific target structured monitoring implementation target would enhance impact recommendation whole approach writing presentation written work across genre implemented whole approach assessment develop ensure consistent impact greater clarity setting whole improvement target ongoing monitoring progress towards target necessary enhance impact deis planning detailed finding recommendation quality good motivated attentive positively disposed instance listening skill could developed experience good take place range context digital technology successfully integrated across curriculum participation department creative cluster initiative impact positively experience infant class good led playful occurs excellent environment local environment used effectively good knowledge local history engage regularly active experience social environmental scientific education sese able describe potential develop skill area literacy outcome commendable articulate eager share appropriately targeted motivation read resultant development culture reading highly commended many achieving good outcome reading current reading intervention successful reading experience could extended use appropriately challenging text léiríonn na daltaí dearcadh dearfach leith na gaeilge agus tá siad spreagtha chun foghlama display positive attitude irish motivated learn identified writing show potential development need ensure writing outcome broadly commensurate reading ability whole approach writing implemented numeracy outcome good demonstrate positivity towards mathematics use mathematical language precisely well developed computational procedural skill quality good overall many example good observed active collaborative methodology well embedded practice share expertise lead aspect development willingly engagement improvement process becomes embedded potential engage greater collective reflection practice tá gnéithe le forbairt maidir le teagasc na gaeilge sna ceachtanna breathnaíodh sonraíodh eiliminití aistriúchán sa teagasc b fhiú cleachtas seo sheachaint aspect development respect irish observed element translation observed advised practice avoided mathematics effective observed overly focused activity would benefited additional plenary session consolidate good emphasis placed use mathematical game although consistently facilitated recognise mathematical principle underlying game content sese effective greater balance acquisition knowledge development skill enhance provision sen effective well coordinated ensuring use classroom plan part continuum becomes embedded practice general target plan specifically stated range effective intervention place number intervention highly effective intervention reviewed regularly ensure contin ...
#  'whole evaluation leadership date inspection inspection activity undertaken meeting principal leadership team meeting representative meeting parent representative review relevant document analysis parent questionnaire observation examination work interaction feedback principal deputy principal parent representative context st michael national rural located village danesfort co kilkenny operates patronage catholic bishop ossory two mainstream class one special education shared another attendance rate forty six enrolled good summary main finding recommendation finding well high quality commendable emphasis physical activity mental well quality leadership good communication decision wider community need reviewed quality good overall improvement planning assessment require attention quality overall good appropriate differentiation behaviour require development support special educational need sen good scope exists review time allocation assessment approach self evaluation sse satisfactory input required ensure impact sse evident classroom practice recommendation ensure special education hour allocated accordance department education guideline circular ensure agreed whole approach provision appropriately differentiated task expected behaviour consistent feature review planning assessment practice ensure area curriculum covered effectively agreed report shared community meeting mechanism involve parent policy formation require development detailed finding recommendation quality quality good overall achieve good standard english mathematics achieving good outcome access differentiated reading material writing task regular monitoring progress outcome appropriate differentiation monitoring component reading writing place differentiated outcome task place mathematics good use made resource enhance experience engaged task experienced difficulty sustained engagement good outcome evident provided appropriately differentiated task ensured sustained engagement good outcome tá cumas na ndaltaí sa ghaeilge mhaith féidir lei na daltaí abairtí iomlána úsáid agus ceisteanna chur agus fhreagairt go muiníneach féidir leo raon mhaith de dánta agus amhráin chur láthair go cumasach bíonn deiseanna ag na daltaí scribhneoireacht dhéanamh ach ba choir níos mó éagsúlacht cur bhfeidhm ability irish good able use complete sentence able pose answer question confidently perform range song poem competently write regularly irish variety writing task provided observed evaluation social environmental scientific education sese music visual art physical education praiseworthy skill development guided discovery enjoyment received due attention development short term planning required ensure breadth balance consistency subject across curriculum quality quality good overall observed ranged good satisfactory good practice observed prepared appropriately differentiated task communicated clear expectation behaviour used range methodology promote purposeful engagement ensure highly effective practice implemented planning preparation good overall subject knowledge setting commendable engagement primary language curriculum plc evident written plan aistear early childhood curriculum framework implemented good standard plan identify clear outcome curriculum subject short term plan place development required ensure timetabled subject area appropriate outcome place fortnight ensure breadth balance across curriculum quality observed special education setting good relationship interaction co operative productive environment awareness personal need evident continuum implemented allocated time used highest level need timetable devised accordance department education guideline circular us diagnostic test identify individual need aspect literacy range diagnostic testing expanded particularly mathematics reading comprehension inform target meet individual need overall quality assessment satisfactory use range assessment tool instance good use made assessment information identify need ...

# %%
tf_idf_vectorizer = TfidfVectorizer(max_df=0.8,min_df=0.1,ngram_range=(2,3))

X = tf_idf_vectorizer.fit_transform(corpus)

# %%
pd.DataFrame(X.toarray(),columns = tf_idf_vectorizer.get_feature_names())
# Out:
#    abairtí iomlána  abairtí iomlána úsáid  abairtí simplí  \
# 0         0.000000               0.000000        0.000000
# 1         0.000000               0.000000        0.000000
# 2         0.000000               0.000000        0.025656
# 3         0.000000               0.000000        0.000000
# 4         0.025187               0.025187        0.000000
#
#    abairtí simplí thuiscint  ability apply  ability apply knowledge  \
# 0                  0.000000       0.000000                 0.000000
# 1                  0.000000       0.000000                 0.000000
# 2                  0.025656       0.025656                 0.025656
# 3                  0.000000       0.000000                 0.000000
# 4                  0.000000       0.000000                 0.000000
#
#    ability highly  ability highly effective  ability irish  \
# 0        0.000000                  0.000000       0.000000
# 1        0.000000                  0.000000       0.000000
# 2        0.025656                  0.025656       0.000000
# 3        0.000000                  0.000000       0.000000
# 4        0.000000                  0.000000       0.025187
#
#    ability irish good  ...  ábalta cumarsáid  ábalta cumarsáid fhiúntach  \
# 0            0.000000  ...          0.000000                    0.000000
# 1            0.000000  ...          0.026876                    0.026876
# 2            0.000000  ...          0.000000                    0.000000
# 3            0.000000  ...          0.000000                    0.000000
# 4            0.025187  ...          0.000000                    0.000000
#
#    éagsúlacht cur  éagsúlacht cur bhfeidhm  úsáid ach  úsáid ach téann  \
# 0        0.000000                 0.000000   0.000000         0.000000
# 1        0.000000                 0.000000   0.000000         0.000000
# 2        0.000000                 0.000000   0.025656         0.025656
# 3        0.000000                 0.000000   0.000000         0.000000
# 4        0.025187                 0.025187   0.000000         0.000000
#
#    úsáid agus  úsáid agus ceisteanna  úsáid mar  úsáid mar bhunús
# 0    0.000000               0.000000   0.000000          0.000000
# 1    0.000000               0.000000   0.026876          0.026876
# 2    0.000000               0.000000   0.000000          0.000000
# 3    0.000000               0.000000   0.000000          0.000000
# 4    0.025187               0.025187   0.000000          0.000000
#
# [5 rows x 6876 columns]

# %%
lda_model = LatentDirichletAllocation(n_components=3).fit(X)

def print_topics(model, vectorizer):
    for idx, topic in enumerate(model.components_):
        print("Topic %d:" % (idx))
        print([(vectorizer.get_feature_names()[i], topic[i])
                        for i in topic.argsort()[:-11:-1]])
        

print_topics(lda_model, tf_idf_vectorizer)
# Out:
# Topic 0:
# [('overall quality', 0.46894118846435257), ('good overall', 0.44221359816395506), ('mainstream setting', 0.43186019055022784), ('communication skill', 0.4160063878522351), ('self assessment', 0.410134826534921), ('provided opportunity', 0.410134826534921), ('good practice', 0.40333445765524845), ('overall quality good', 0.40166171384688765), ('quality good overall', 0.398860395515905), ('leadership role', 0.3969425833205068)]
# Topic 1:
# [('priority need', 0.41995798281331564), ('assessment data', 0.41995269625893683), ('sse process', 0.38724952923649136), ('questionnaire returned', 0.38695396395125015), ('skill progressed', 0.38695396395125015), ('sharing good practice', 0.38695396395125015), ('address priority need', 0.38695396395125015), ('gathered used consistently', 0.38695396395125015), ('gathered used', 0.38695396395125015), ('address priority', 0.38695396395125015)]
# Topic 2:
# [('approach assessment', 0.41774286726073573), ('require development', 0.4166461677266475), ('good outcome', 0.4155495022053489), ('greater clarity', 0.4128138301410403), ('required ensure', 0.408736441070394), ('appropriately differentiated task', 0.408736441070394), ('development required', 0.408736441070394), ('appropriately differentiated', 0.408736441070394), ('differentiated task', 0.408736441070394), ('good overall', 0.4049611037135544)]

# %%
example = ["please have a positive attitude towards assessment data and written work"]

example_vectorized = tf_idf_vectorizer.transform(example)

lda_vectors = lda_model.transform(example_vectorized)
print(lda_vectors)

#print("topic 0 :", lda_vectors[0][0])
#print("topic 1 :", lda_vectors[0][1])
# Out:
# [[0.26693105 0.73306895]]

# %% [markdown]
# ## vectorizing the data: n-grams
